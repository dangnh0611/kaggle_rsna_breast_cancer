# %%
import os
import numpy as np
import pandas as pd
import sys
from tqdm import tqdm
from pydicom import dcmread
import shutil
import subprocess as sp

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)

# %%
def get_dicom_meta_from_file(dicom_root_dir, patient_id, img_id, extension = 'dcm'):
    dicom_path = os.path.join(dicom_root_dir, f'{patient_id}/{img_id}.{extension}')
    return dcmread(dicom_path, stop_before_pixels=True)


def get_dicom_meta(dicom_root_dir, dicom_df, extension = 'dcm'):
    dicom_data = dict()
    keywords = set()
    dicom_df = dicom_df[["patient_id", "image_id"]].copy()

    for index, row in tqdm(dicom_df.iterrows()):
        patient_id = row["patient_id"]
        image_id = row["image_id"]
        dicom = get_dicom_meta_from_file(dicom_root_dir, patient_id, image_id, extension)
        assert dicom.get('ModalityLUTSequence', None) is None
        if patient_id not in dicom_data:
            dicom_data[patient_id] = dict()
        if image_id not in dicom_data[patient_id]:
            dicom_data[patient_id][image_id] = dict()
        for feature in dicom.iterall():
            dicom_data[patient_id][image_id][feature.keyword] = feature.value
            keywords.add(feature.keyword)
    for keyword in keywords:
        dicom_df[keyword] = dicom_df[["patient_id", "image_id"]].apply(lambda x: np.nan if keyword not in dicom_data[x.patient_id][x.image_id] else dicom_data[x.patient_id][x.image_id][keyword], axis=1)
    print(": Keywords extracted from dicom files:")
    for keyword in keywords:
        print("--> {}".format(keyword))
    return dicom_df

# %% [markdown]
# ### Competition data

# %%
comp_df = pd.read_csv('/home/dangnh36/datasets/.comp/rsna/cv/v1/train_fold_0.csv')
print(comp_df.columns)
comp_df

# %% [markdown]
# ### Vindr

# %%
ROOT_DIR = '/home/dangnh36/datasets/.comp/rsna/external/vindr/'
DCM_ROOT_DIR = os.path.join(ROOT_DIR, 'images')

# %%
df = pd.read_csv(os.path.join(ROOT_DIR, 'breast-level_annotations.csv'))
df

# %%
df.columns

# %%
df.rename(columns = {'study_id': 'patient_id', 'view_position': 'view',
                     'breast_birads': 'BIRADS', 'breast_density': 'density'}, inplace = True)
df.BIRADS = df.BIRADS.apply(lambda x: int(x.split()[-1]))
df.density = df.density.apply(lambda x: x.split()[-1] if type(x) == str else x)
df

# %%
df.density.value_counts()

# %%
df.BIRADS.value_counts()

# %%
meta_df = get_dicom_meta(DCM_ROOT_DIR, df, extension = 'dicom')

# %%
meta_df

# %%
meta_df[~meta_df.VOILUTSequence.isna()]

# %%
arr = np.array(meta_df.at[19965, 'LUTData'])
arr

# %%
arr.max(), arr.mean(), arr.min()

# %%
list(set(arr))

# %%
arr[2048]

# %%
meta_df.to_csv(os.path.join(ROOT_DIR, 'dicom_meta_only.csv'), index = False)

# %%
meta_df.rename(columns = {name:'__' + name for name in meta_df.columns if name != 'image_id'}, inplace = True)
merged = pd.merge(
    df,
    meta_df,
    how="inner",
    on='image_id',
    left_on=None,
    right_on=None,
    left_index=False,
    right_index=False,
    sort=False,
    suffixes=("??", "__"),
    copy=True,
    indicator=False,
    validate='1:1',
)
merged

# %%
merged.at[0, '__VOILUTSequence'][1].get('LUTData', None)

# %%
merged.at[0, '__VOILUTSequence'][1].get('LUTData', None)

# %%
merged.at[0, '__VOILUTSequence'][0].get('LUTData', None)

# %%
merged.at[0, '__VOILUTSequence'][2]

# %%
merged.columns

# %%
merged.split.value_counts()

# %%
merged['__hasVOILUTSequence'] = merged['__VOILUTSequence'].isna()
merged['__hasLUTDescriptor'] = merged['__LUTDescriptor'].isna()
merged['__hasLUTData'] = merged['__LUTData'].isna()

# %%
merged.rename(columns = {'__PatientAge': 'age'}, inplace = True)

# %%
merged['__PhotometricInterpretation'].value_counts()

# %%
merged['__LUTExplanation'].value_counts()

# %%
merged = merged[['patient_id', 'series_id', 'image_id', 'laterality', 'view', 'age',
       'BIRADS', 'density', 'split', '__SmallestImagePixelValue',
       '__PixelRepresentation', '__SOPInstanceUID', '__PatientWeight', '__WindowWidth',
       '__PixelPaddingValue', '__BodyPartExamined',
       '__StudyInstanceUID', '__ViewPosition', '__LargestImagePixelValue',
       '__PixelSpacing', '__PixelPaddingRangeLimit',
       '__SeriesInstanceUID', '__SamplesPerPixel', '__PresentationLUTShape',
                 '__WindowCenterWidthExplanation', '__WindowCenter',
       '__ImagerPixelSpacing', '__VOILUTFunction', '__RescaleIntercept', '__RescaleSlope',
        '__PhotometricInterpretation', '__Rows', '__Columns',
                 '__hasVOILUTSequence', '__hasLUTDescriptor', '__hasLUTData' ]]
merged

# %%
merged.BIRADS.value_counts()

# %%
merged['cancer'] = merged.BIRADS.apply(lambda x: 1 if x == 5 else 0)

# %%
merged.cancer.value_counts()

# %%
merged.to_csv(os.path.join(ROOT_DIR, 'all_labels.csv'), index = False)

# %%
import dicomsdl

# %%
merged[merged['__hasVOILUTSequence'] == True]

# %%
dcm = dicomsdl.open('/home/dangnh36/datasets/.comp/rsna/external/vindr/images/b8d273e8601f348d3664778dae0e7e0b/d8125545210c08e1b1793a5af6458ee2.dicom')

# %%
dcm.VOILUTSequence[0]

# %% [markdown]
# ### MiniDDSM

# %%
ROOT_DIR = '/home/dangnh36/datasets/.comp/rsna/external/miniddsm/'
DCM_ROOT_DIR = os.path.join(ROOT_DIR, 'MINI-DDSM-Complete-PNG-16')

# %%
df = pd.read_excel(os.path.join(ROOT_DIR, 'Data-MoreThanTwoMasks', 'Data-MoreThanTwoMasks.xlsx'))
df

# %%
df['patient_id'] = df['fileName'].apply(lambda x: x.split('.')[0])
df['image_id'] = df['patient_id'] + '@' + df['Side'] + '@' + df['View']
df

# %%
df.columns

# %%
df.patient_id.nunique()

# %%
df.image_id.nunique()

# %%
for patient_id, sub_df in tqdm(df.groupby('patient_id')):
    assert sub_df.Status.nunique() == 1

# %%
for patient_id, sub_df in tqdm(df.groupby(['patient_id'])):
    sub_df = sub_df.reset_index(drop = True)
    assert sub_df.Status.nunique() == 1
    status = sub_df.at[0, 'Status']
    no_annotation = True
    for j in range(len(sub_df)):
        if type(sub_df.at[j, 'Tumour_Contour']) == str:
            if len(sub_df.at[j, 'Tumour_Contour']) > 5:
                no_annotation = False
    if status == 'Normal':
        if not no_annotation:
            display(sub_df)
            break
    else:
        if no_annotation:
            display(sub_df)
            break

# %%
cancer_dict = {}
for patient_id, sub_df in tqdm(df.groupby(['patient_id', 'Side'])):
    breast = '@'.join(patient_id)
    sub_df = sub_df.reset_index(drop = True)
    assert sub_df.Status.nunique() == 1
    status = sub_df.at[0, 'Status']
    no_annotation = True
    for j in range(len(sub_df)):
        if type(sub_df.at[j, 'Tumour_Contour']) == str:
            if len(sub_df.at[j, 'Tumour_Contour']) > 5:
                no_annotation = False
    if status == 'Normal':
        if not no_annotation:
            raise AssertionError()
        else:
            cancer_dict[breast] = 0
    elif status == 'Benign':
        cancer_dict[breast] = 0
    elif status == 'Cancer':
        if no_annotation:
            cancer_dict[breast] = 0
        else:
            cancer_dict[breast] = 1
    else:
        raise AssertionError()

# %%
cancer_dict

# %%
df['cancer'] = -1

# %%
for i in tqdm(range(len(df))):
    breast = df.at[i, 'patient_id'] + '@' + df.at[i, 'Side']
    df.at[i, 'cancer'] = cancer_dict[breast]
df

# %%
df[df.cancer == 1].Status.value_counts()

# %%
df[df.cancer == 1]['Tumour_Contour'].isna().any()

# %%
(df[(df.cancer == 0) & (df.Status=='Cancer')]['Tumour_Contour'].apply(lambda x: len(x)) > 1).any()

# %%
df.cancer.value_counts()

# %%
df.columns

# %%
src_dir = os.path.join(ROOT_DIR, 'MINI-DDSM-Complete-PNG-16')
dst_dir = os.path.join(ROOT_DIR, 'png16_v2')
for i in tqdm(range(len(df))):
    status = df.at[i, 'Status']
    patient_id = df.at[i, 'patient_id']
    patient_idx = patient_id.split('_')[1]
    image_id = df.at[i, 'image_id']
    name = df.at[i, 'fileName']
    src_path = os.path.join(src_dir, status, patient_idx, name)
    dst_path = os.path.join(dst_dir, patient_id, f'{image_id}.png')
    os.makedirs(os.path.dirname(dst_path), exist_ok=True)
    shutil.copy2(src_path, dst_path)

# %%
df.Density.value_counts()

# %%
# LEFT, RIGHT --> L, R
df['Side'] = df['Side'].apply(lambda x: x[0])

density_map = {1: 'A', 2: 'B', 3: 'C', 4: 'D', 0: 'A'}
df['Density'] = df['Density'].apply(lambda x: density_map[x])

# %%
df.drop(columns = ['fullPath', 'fileName', 'Tumour_Contour', 'Tumour_Contour2',
                   'Tumour_Contour3', 'Tumour_Contour4', 'Tumour_Contour5',
                   'Tumour_Contour6'], inplace = True)
df.rename(columns = {'View': 'view', 'Side': 'laterality',
                    'Status': 'ddsm_ori_status', 'Age': 'age', 'Density': 'density',
                    }, inplace = True)

# %%
df = df[['patient_id', 'image_id', 'view', 'laterality', 'density', 'age', 'ddsm_ori_status', 'cancer']]
df

# %%
df.to_csv(os.path.join(ROOT_DIR, 'label_v2.csv'), index = False)

# %% [markdown]
# ### CMMD

# %%
ROOT_DIR = '/home/dangnh36/datasets/.comp/rsna/external/cmmd'
DCM_ROOT_DIR = os.path.join(ROOT_DIR, 'CMMD')

# %%
df = pd.read_csv(os.path.join(ROOT_DIR, 'CMMD_label.csv'))
df
# Out:
#           ID1 LeftRight  Age  number    abnormality classification    subtype
# 0     D1-0001         R   44       2  calcification         Benign        NaN
# 1     D1-0002         L   40       2  calcification         Benign        NaN
# ...       ...       ...  ...     ...            ...            ...        ...
# 1870  D2-0748         R   29       2           mass      Malignant  Luminal B
# 1871  D2-0749         L   42       2           mass      Malignant  Luminal B
#
# [1872 rows x 7 columns]

# %%
df.classification.value_counts()
# Out:
# Malignant    1316
# Benign        556
# Name: classification, dtype: int64

# %%
df[df.classification.isna()]
# Out:
# Empty DataFrame
# Columns: [ID1, LeftRight, Age, number, abnormality, classification, subtype]
# Index: []

# %%
src_dir = DCM_ROOT_DIR
dst_dir = os.path.join(ROOT_DIR, 'dicoms_v2')

for patient_id, sub_df in tqdm(df.groupby('ID1')):
    tmp_dir = os.path.join(src_dir, patient_id)
    tmp2_dirs = os.listdir(tmp_dir)
    assert len(tmp2_dirs) == 1
    tmp3_dirs = os.listdir(os.path.join(tmp_dir, tmp2_dirs[0]))
    assert len(tmp3_dirs) == 1
    src_img_dir = os.path.join(tmp_dir, tmp2_dirs[0], tmp3_dirs[0])
    img_names = os.listdir(src_img_dir)
#     if len(img_names) != sub_df.number.sum():
#         print(patient_id, img_names)
#         print(sub_df.number)

#     for img_name in img_names:
#         src_img_path = os.path.join(src_img_dir, img_name)
#         dst_img_path = os.path.join(dst_dir, patient_id, f'{patient_id}_{img_name}')
#         os.makedirs(os.path.dirname(dst_img_path), exist_ok=True)
#         shutil.copy2(src_img_path, dst_img_path)
# Out:
# 100%|███████████████████████████████████████| 1775/1775 [00:01<00:00, 1155.52it/s]

# %%
all_patient_ids = []
all_image_ids = []

patients = os.listdir(dst_dir)
for patient in patients:
    patient_dir = os.path.join(dst_dir, patient)
    image_names = os.listdir(patient_dir)
    for image_name in image_names:
        all_patient_ids.append(patient)
        all_image_ids.append(image_name.split('.dcm')[0])
dicom_df = pd.DataFrame({
    'patient_id': all_patient_ids,
    'image_id': all_image_ids
})
dicom_df
# Out:
#      patient_id     image_id
# 0       D1-0830  D1-0830_1-1
# 1       D1-0830  D1-0830_1-4
# ...         ...          ...
# 5200    D2-0448  D2-0448_1-4
# 5201    D2-0448  D2-0448_1-3
#
# [5202 rows x 2 columns]

# %%
dicom_df = get_dicom_meta(dst_dir, dicom_df, extension = 'dcm')
dicom_df
# Out:
# 5202it [01:28, 58.78it/s]
# : Keywords extracted from dicom files:
# -->
# --> HighBit
# --> PixelIntensityRelationshipSign
# --> AcquisitionContextSequence
# --> StudyDate
# --> WindowCenter
# --> WindowWidth
# --> PositionerType
# --> InstanceCreatorUID
# --> DetectorType
# --> RescaleSlope
# --> ImageType
# --> AccessionNumber
# --> RescaleType
# --> DeidentificationMethodCodeSequence
# --> PixelRepresentation
# --> PatientSex
# --> ImagerPixelSpacing
# --> PatientName
# --> PatientBirthDate
# --> DeidentificationMethod
# --> AcquisitionDate
# --> PatientAge
# --> SeriesNumber
# --> PhotometricInterpretation
# --> SeriesInstanceUID
# --> ContentTime
# --> InstanceCreationTime
# --> StudyID
# --> BurnedInAnnotation
# --> BitsStored
# --> CodeValue
# --> CodeMeaning
# --> AnatomicRegionSequence
# --> SOPClassUID
# --> ViewCodeSequence
# --> SamplesPerPixel
# --> PatientOrientation
# --> InstanceNumber
# --> PixelIntensityRelationship
# --> CodingSchemeDesignator
# --> LossyImageCompression
# --> OrganExposed
# --> LongitudinalTemporalInformationModified
# --> StudyInstanceUID
# --> SOPInstanceUID
# --> ContentDate
# --> ImageLaterality
# --> Modality
# --> PatientID
# --> InstanceCreationDate
# --> PresentationLUTShape
# --> PresentationIntentType
# --> RescaleIntercept
# --> SeriesDate
# --> BodyPartExamined
# --> ReferringPhysicianName
# --> SeriesTime
# --> Manufacturer
# --> BitsAllocated
# --> PatientIdentityRemoved
# --> Columns
# --> SpecificCharacterSet
# --> WindowCenterWidthExplanation
# --> VOILUTFunction
# --> AcquisitionTime
# --> ViewModifierCodeSequence
# --> Rows
# --> StudyTime
#      patient_id     image_id            HighBit  \
# 0       D1-0830  D1-0830_1-1  12391759        7
# 1       D1-0830  D1-0830_1-4  12391759        7
# ...         ...          ...       ...      ...
# 5200    D2-0448  D2-0448_1-4  12391759        7
# 5201    D2-0448  D2-0448_1-3  12391759        7
#
#       PixelIntensityRelationshipSign AcquisitionContextSequence StudyDate  \
# 0                                 -1                         []  20100718
# 1                                 -1                         []  20100718
# ...                              ...                        ...       ...
# 5200                              -1                         []  20100718
# 5201                              -1                         []  20100718
#
#       WindowCenter  WindowWidth PositionerType  \
# 0            128.0        256.0   MAMMOGRAPHIC
# 1            128.0        256.0   MAMMOGRAPHIC
# ...            ...          ...            ...
# 5200         128.0        256.0   MAMMOGRAPHIC
# 5201         128.0        256.0   MAMMOGRAPHIC
#
#                                      InstanceCreatorUID  DetectorType  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...  SCINTILLATOR
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...  SCINTILLATOR
# ...                                                 ...           ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...  SCINTILLATOR
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...  SCINTILLATOR
#
#       RescaleSlope           ImageType AccessionNumber RescaleType  \
# 0              1.0  [DERIVED, PRIMARY]                          US
# 1              1.0  [DERIVED, PRIMARY]                          US
# ...            ...                 ...             ...         ...
# 5200           1.0  [DERIVED, PRIMARY]                          US
# 5201           1.0  [DERIVED, PRIMARY]                          US
#
#                      DeidentificationMethodCodeSequence  PixelRepresentation  \
# 0     [[(0008, 0100) Code Value                     ...                    0
# 1     [[(0008, 0100) Code Value                     ...                    0
# ...                                                 ...                  ...
# 5200  [[(0008, 0100) Code Value                     ...                    0
# 5201  [[(0008, 0100) Code Value                     ...                    0
#
#      PatientSex          ImagerPixelSpacing            PatientName  \
# 0             F  [0.094090909, 0.094090909]  (D, 1, -, 0, 8, 3, 0)
# 1             F  [0.094090909, 0.094090909]  (D, 1, -, 0, 8, 3, 0)
# ...         ...                         ...                    ...
# 5200          F  [0.094090909, 0.094090909]  (D, 2, -, 0, 4, 4, 8)
# 5201          F  [0.094090909, 0.094090909]  (D, 2, -, 0, 4, 4, 8)
#
#      PatientBirthDate                          DeidentificationMethod  \
# 0                      Per DICOM PS 3.15 AnnexE. Details in 0012,0064
# 1                      Per DICOM PS 3.15 AnnexE. Details in 0012,0064
# ...               ...                                             ...
# 5200                   Per DICOM PS 3.15 AnnexE. Details in 0012,0064
# 5201                   Per DICOM PS 3.15 AnnexE. Details in 0012,0064
#
#      AcquisitionDate PatientAge  SeriesNumber PhotometricInterpretation  \
# 0           20100718       063Y             1               MONOCHROME2
# 1           20100718       063Y             1               MONOCHROME2
# ...              ...        ...           ...                       ...
# 5200        20100718       053Y             1               MONOCHROME2
# 5201        20100718       053Y             1               MONOCHROME2
#
#                                       SeriesInstanceUID ContentTime  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.320712920134...      000000
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.320712920134...      000000
# ...                                                 ...         ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.378084371300...      000000
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.378084371300...      000000
#
#      InstanceCreationTime StudyID BurnedInAnnotation  BitsStored  CodeValue  \
# 0                  120428                         NO           8  399162004
# 1                  120430                         NO           8  399368009
# ...                   ...     ...                ...         ...        ...
# 5200               124254                         NO           8  399368009
# 5201               124253                         NO           8  399162004
#
#                 CodeMeaning  \
# 0             cranio-caudal
# 1     medio-lateral oblique
# ...                     ...
# 5200  medio-lateral oblique
# 5201          cranio-caudal
#
#                                  AnatomicRegionSequence  \
# 0     [[(0008, 0100) Code Value                     ...
# 1     [[(0008, 0100) Code Value                     ...
# ...                                                 ...
# 5200  [[(0008, 0100) Code Value                     ...
# 5201  [[(0008, 0100) Code Value                     ...
#
#                       SOPClassUID  \
# 0     1.2.840.10008.5.1.4.1.1.1.2
# 1     1.2.840.10008.5.1.4.1.1.1.2
# ...                           ...
# 5200  1.2.840.10008.5.1.4.1.1.1.2
# 5201  1.2.840.10008.5.1.4.1.1.1.2
#
#                                        ViewCodeSequence  SamplesPerPixel  \
# 0     [[(0008, 0100) Code Value                     ...                1
# 1     [[(0008, 0100) Code Value                     ...                1
# ...                                                 ...              ...
# 5200  [[(0008, 0100) Code Value                     ...                1
# 5201  [[(0008, 0100) Code Value                     ...                1
#
#      PatientOrientation  InstanceNumber PixelIntensityRelationship  \
# 0                [A, R]               1                        LOG
# 1               [P, FL]               4                        LOG
# ...                 ...             ...                        ...
# 5200            [P, FL]               4                        LOG
# 5201             [P, L]               3                        LOG
#
#      CodingSchemeDesignator LossyImageCompression OrganExposed  \
# 0                       SCT                    00       BREAST
# 1                       SCT                    00       BREAST
# ...                     ...                   ...          ...
# 5200                    SCT                    00       BREAST
# 5201                    SCT                    00       BREAST
#
#      LongitudinalTemporalInformationModified  \
# 0                                   MODIFIED
# 1                                   MODIFIED
# ...                                      ...
# 5200                                MODIFIED
# 5201                                MODIFIED
#
#                                        StudyInstanceUID  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.160257839898...
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.160257839898...
# ...                                                 ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.744773683160...
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.744773683160...
#
#                                          SOPInstanceUID ContentDate  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.244359496749...    20100718
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.159807368290...    20100718
# ...                                                 ...         ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.704200754105...    20100718
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.170184140124...    20100718
#
#      ImageLaterality Modality PatientID InstanceCreationDate  \
# 0                  L       MG   D1-0830             20170818
# 1                  R       MG   D1-0830             20170818
# ...              ...      ...       ...                  ...
# 5200               R       MG   D2-0448             20170818
# 5201               R       MG   D2-0448             20170818
#
#      PresentationLUTShape PresentationIntentType  RescaleIntercept SeriesDate  \
# 0                IDENTITY       FOR PRESENTATION               0.0   20100718
# 1                IDENTITY       FOR PRESENTATION               0.0   20100718
# ...                   ...                    ...               ...        ...
# 5200             IDENTITY       FOR PRESENTATION               0.0   20100718
# 5201             IDENTITY       FOR PRESENTATION               0.0   20100718
#
#      BodyPartExamined ReferringPhysicianName SeriesTime Manufacturer  \
# 0              BREAST                     ()     000000
# 1              BREAST                     ()     000000
# ...               ...                    ...        ...          ...
# 5200           BREAST                     ()     000000
# 5201           BREAST                     ()     000000
#
#       BitsAllocated PatientIdentityRemoved  Columns SpecificCharacterSet  \
# 0                 8                    YES     1914           ISO_IR 100
# 1                 8                    YES     1914           ISO_IR 100
# ...             ...                    ...      ...                  ...
# 5200              8                    YES     1914           ISO_IR 100
# 5201              8                    YES     1914           ISO_IR 100
#
#      WindowCenterWidthExplanation VOILUTFunction AcquisitionTime  \
# 0        Full width of 8 bit data        SIGMOID          000000
# 1        Full width of 8 bit data        SIGMOID          000000
# ...                           ...            ...             ...
# 5200     Full width of 8 bit data        SIGMOID          000000
# 5201     Full width of 8 bit data        SIGMOID          000000
#
#      ViewModifierCodeSequence  Rows StudyTime
# 0                          []  2294    000000
# 1                          []  2294    000000
# ...                       ...   ...       ...
# 5200                       []  2294    000000
# 5201                       []  2294    000000
#
# [5202 rows x 71 columns]

# %%
df.rename(columns = {'ID1': 'patient_id', 'LeftRight': 'laterality'}, inplace = True)

# %%
dicom_df.rename(columns = {'ImageLaterality': 'laterality'}, inplace = True)

# %%
dicom_df.rename(columns = {name:'__' + name for name in dicom_df.columns if name not in ['patient_id', 'laterality']}, inplace = True)

# %%
dicom_df
# Out:
#      patient_id   __image_id        __  __HighBit  \
# 0       D1-0830  D1-0830_1-1  12391759          7
# 1       D1-0830  D1-0830_1-4  12391759          7
# ...         ...          ...       ...        ...
# 5200    D2-0448  D2-0448_1-4  12391759          7
# 5201    D2-0448  D2-0448_1-3  12391759          7
#
#       __PixelIntensityRelationshipSign __AcquisitionContextSequence  \
# 0                                   -1                           []
# 1                                   -1                           []
# ...                                ...                          ...
# 5200                                -1                           []
# 5201                                -1                           []
#
#      __StudyDate  __WindowCenter  __WindowWidth __PositionerType  \
# 0       20100718           128.0          256.0     MAMMOGRAPHIC
# 1       20100718           128.0          256.0     MAMMOGRAPHIC
# ...          ...             ...            ...              ...
# 5200    20100718           128.0          256.0     MAMMOGRAPHIC
# 5201    20100718           128.0          256.0     MAMMOGRAPHIC
#
#                                    __InstanceCreatorUID __DetectorType  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...   SCINTILLATOR
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...   SCINTILLATOR
# ...                                                 ...            ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...   SCINTILLATOR
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...   SCINTILLATOR
#
#       __RescaleSlope         __ImageType __AccessionNumber __RescaleType  \
# 0                1.0  [DERIVED, PRIMARY]                              US
# 1                1.0  [DERIVED, PRIMARY]                              US
# ...              ...                 ...               ...           ...
# 5200             1.0  [DERIVED, PRIMARY]                              US
# 5201             1.0  [DERIVED, PRIMARY]                              US
#
#                    __DeidentificationMethodCodeSequence  \
# 0     [[(0008, 0100) Code Value                     ...
# 1     [[(0008, 0100) Code Value                     ...
# ...                                                 ...
# 5200  [[(0008, 0100) Code Value                     ...
# 5201  [[(0008, 0100) Code Value                     ...
#
#       __PixelRepresentation __PatientSex        __ImagerPixelSpacing  \
# 0                         0            F  [0.094090909, 0.094090909]
# 1                         0            F  [0.094090909, 0.094090909]
# ...                     ...          ...                         ...
# 5200                      0            F  [0.094090909, 0.094090909]
# 5201                      0            F  [0.094090909, 0.094090909]
#
#               __PatientName __PatientBirthDate  \
# 0     (D, 1, -, 0, 8, 3, 0)
# 1     (D, 1, -, 0, 8, 3, 0)
# ...                     ...                ...
# 5200  (D, 2, -, 0, 4, 4, 8)
# 5201  (D, 2, -, 0, 4, 4, 8)
#
#                             __DeidentificationMethod __AcquisitionDate  \
# 0     Per DICOM PS 3.15 AnnexE. Details in 0012,0064          20100718
# 1     Per DICOM PS 3.15 AnnexE. Details in 0012,0064          20100718
# ...                                              ...               ...
# 5200  Per DICOM PS 3.15 AnnexE. Details in 0012,0064          20100718
# 5201  Per DICOM PS 3.15 AnnexE. Details in 0012,0064          20100718
#
#      __PatientAge  __SeriesNumber __PhotometricInterpretation  \
# 0            063Y               1                 MONOCHROME2
# 1            063Y               1                 MONOCHROME2
# ...           ...             ...                         ...
# 5200         053Y               1                 MONOCHROME2
# 5201         053Y               1                 MONOCHROME2
#
#                                     __SeriesInstanceUID __ContentTime  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.320712920134...        000000
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.320712920134...        000000
# ...                                                 ...           ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.378084371300...        000000
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.378084371300...        000000
#
#      __InstanceCreationTime __StudyID __BurnedInAnnotation  __BitsStored  \
# 0                    120428                             NO             8
# 1                    120430                             NO             8
# ...                     ...       ...                  ...           ...
# 5200                 124254                             NO             8
# 5201                 124253                             NO             8
#
#      __CodeValue          __CodeMeaning  \
# 0      399162004          cranio-caudal
# 1      399368009  medio-lateral oblique
# ...          ...                    ...
# 5200   399368009  medio-lateral oblique
# 5201   399162004          cranio-caudal
#
#                                __AnatomicRegionSequence  \
# 0     [[(0008, 0100) Code Value                     ...
# 1     [[(0008, 0100) Code Value                     ...
# ...                                                 ...
# 5200  [[(0008, 0100) Code Value                     ...
# 5201  [[(0008, 0100) Code Value                     ...
#
#                     __SOPClassUID  \
# 0     1.2.840.10008.5.1.4.1.1.1.2
# 1     1.2.840.10008.5.1.4.1.1.1.2
# ...                           ...
# 5200  1.2.840.10008.5.1.4.1.1.1.2
# 5201  1.2.840.10008.5.1.4.1.1.1.2
#
#                                      __ViewCodeSequence  __SamplesPerPixel  \
# 0     [[(0008, 0100) Code Value                     ...                  1
# 1     [[(0008, 0100) Code Value                     ...                  1
# ...                                                 ...                ...
# 5200  [[(0008, 0100) Code Value                     ...                  1
# 5201  [[(0008, 0100) Code Value                     ...                  1
#
#      __PatientOrientation  __InstanceNumber __PixelIntensityRelationship  \
# 0                  [A, R]                 1                          LOG
# 1                 [P, FL]                 4                          LOG
# ...                   ...               ...                          ...
# 5200              [P, FL]                 4                          LOG
# 5201               [P, L]                 3                          LOG
#
#      __CodingSchemeDesignator __LossyImageCompression __OrganExposed  \
# 0                         SCT                      00         BREAST
# 1                         SCT                      00         BREAST
# ...                       ...                     ...            ...
# 5200                      SCT                      00         BREAST
# 5201                      SCT                      00         BREAST
#
#      __LongitudinalTemporalInformationModified  \
# 0                                     MODIFIED
# 1                                     MODIFIED
# ...                                        ...
# 5200                                  MODIFIED
# 5201                                  MODIFIED
#
#                                      __StudyInstanceUID  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.160257839898...
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.160257839898...
# ...                                                 ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.744773683160...
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.744773683160...
#
#                                        __SOPInstanceUID __ContentDate  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.244359496749...      20100718
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.159807368290...      20100718
# ...                                                 ...           ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.704200754105...      20100718
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.170184140124...      20100718
#
#      laterality __Modality __PatientID __InstanceCreationDate  \
# 0             L         MG     D1-0830               20170818
# 1             R         MG     D1-0830               20170818
# ...         ...        ...         ...                    ...
# 5200          R         MG     D2-0448               20170818
# 5201          R         MG     D2-0448               20170818
#
#      __PresentationLUTShape __PresentationIntentType  __RescaleIntercept  \
# 0                  IDENTITY         FOR PRESENTATION                 0.0
# 1                  IDENTITY         FOR PRESENTATION                 0.0
# ...                     ...                      ...                 ...
# 5200               IDENTITY         FOR PRESENTATION                 0.0
# 5201               IDENTITY         FOR PRESENTATION                 0.0
#
#      __SeriesDate __BodyPartExamined __ReferringPhysicianName __SeriesTime  \
# 0        20100718             BREAST                       ()       000000
# 1        20100718             BREAST                       ()       000000
# ...           ...                ...                      ...          ...
# 5200     20100718             BREAST                       ()       000000
# 5201     20100718             BREAST                       ()       000000
#
#      __Manufacturer  __BitsAllocated __PatientIdentityRemoved  __Columns  \
# 0                                  8                      YES       1914
# 1                                  8                      YES       1914
# ...             ...              ...                      ...        ...
# 5200                               8                      YES       1914
# 5201                               8                      YES       1914
#
#      __SpecificCharacterSet __WindowCenterWidthExplanation __VOILUTFunction  \
# 0                ISO_IR 100       Full width of 8 bit data          SIGMOID
# 1                ISO_IR 100       Full width of 8 bit data          SIGMOID
# ...                     ...                            ...              ...
# 5200             ISO_IR 100       Full width of 8 bit data          SIGMOID
# 5201             ISO_IR 100       Full width of 8 bit data          SIGMOID
#
#      __AcquisitionTime __ViewModifierCodeSequence  __Rows __StudyTime
# 0               000000                         []    2294      000000
# 1               000000                         []    2294      000000
# ...                ...                        ...     ...         ...
# 5200            000000                         []    2294      000000
# 5201            000000                         []    2294      000000
#
# [5202 rows x 71 columns]

# %%
dicom_df.groupby(['patient_id', 'laterality']).count()
# Out:
#                        __image_id  __  __HighBit  \
# patient_id laterality
# D1-0001    R                    2   2          2
# D1-0002    L                    2   2          2
# ...                           ...  ..        ...
# D2-0749    L                    2   2          2
#            R                    2   2          2
#
#                        __PixelIntensityRelationshipSign  \
# patient_id laterality
# D1-0001    R                                          2
# D1-0002    L                                          2
# ...                                                 ...
# D2-0749    L                                          2
#            R                                          2
#
#                        __AcquisitionContextSequence  __StudyDate  \
# patient_id laterality
# D1-0001    R                                      2            2
# D1-0002    L                                      2            2
# ...                                             ...          ...
# D2-0749    L                                      2            2
#            R                                      2            2
#
#                        __WindowCenter  __WindowWidth  __PositionerType  \
# patient_id laterality
# D1-0001    R                        2              2                 2
# D1-0002    L                        2              2                 2
# ...                               ...            ...               ...
# D2-0749    L                        2              2                 2
#            R                        2              2                 2
#
#                        __InstanceCreatorUID  __DetectorType  __RescaleSlope  \
# patient_id laterality
# D1-0001    R                              2               2               2
# D1-0002    L                              2               2               2
# ...                                     ...             ...             ...
# D2-0749    L                              2               2               2
#            R                              2               2               2
#
#                        __ImageType  __AccessionNumber  __RescaleType  \
# patient_id laterality
# D1-0001    R                     2                  2              2
# D1-0002    L                     2                  2              2
# ...                            ...                ...            ...
# D2-0749    L                     2                  2              2
#            R                     2                  2              2
#
#                        __DeidentificationMethodCodeSequence  \
# patient_id laterality
# D1-0001    R                                              2
# D1-0002    L                                              2
# ...                                                     ...
# D2-0749    L                                              2
#            R                                              2
#
#                        __PixelRepresentation  __PatientSex  \
# patient_id laterality
# D1-0001    R                               2             2
# D1-0002    L                               2             2
# ...                                      ...           ...
# D2-0749    L                               2             2
#            R                               2             2
#
#                        __ImagerPixelSpacing  __PatientName  \
# patient_id laterality
# D1-0001    R                              2              2
# D1-0002    L                              2              2
# ...                                     ...            ...
# D2-0749    L                              2              2
#            R                              2              2
#
#                        __PatientBirthDate  __DeidentificationMethod  \
# patient_id laterality
# D1-0001    R                            2                         2
# D1-0002    L                            2                         2
# ...                                   ...                       ...
# D2-0749    L                            2                         2
#            R                            2                         2
#
#                        __AcquisitionDate  __PatientAge  __SeriesNumber  \
# patient_id laterality
# D1-0001    R                           2             2               2
# D1-0002    L                           2             2               2
# ...                                  ...           ...             ...
# D2-0749    L                           2             2               2
#            R                           2             2               2
#
#                        __PhotometricInterpretation  __SeriesInstanceUID  \
# patient_id laterality
# D1-0001    R                                     2                    2
# D1-0002    L                                     2                    2
# ...                                            ...                  ...
# D2-0749    L                                     2                    2
#            R                                     2                    2
#
#                        __ContentTime  __InstanceCreationTime  __StudyID  \
# patient_id laterality
# D1-0001    R                       2                       2          2
# D1-0002    L                       2                       2          2
# ...                              ...                     ...        ...
# D2-0749    L                       2                       2          2
#            R                       2                       2          2
#
#                        __BurnedInAnnotation  __BitsStored  __CodeValue  \
# patient_id laterality
# D1-0001    R                              2             2            2
# D1-0002    L                              2             2            2
# ...                                     ...           ...          ...
# D2-0749    L                              2             2            2
#            R                              2             2            2
#
#                        __CodeMeaning  __AnatomicRegionSequence  __SOPClassUID  \
# patient_id laterality
# D1-0001    R                       2                         2              2
# D1-0002    L                       2                         2              2
# ...                              ...                       ...            ...
# D2-0749    L                       2                         2              2
#            R                       2                         2              2
#
#                        __ViewCodeSequence  __SamplesPerPixel  \
# patient_id laterality
# D1-0001    R                            2                  2
# D1-0002    L                            2                  2
# ...                                   ...                ...
# D2-0749    L                            2                  2
#            R                            2                  2
#
#                        __PatientOrientation  __InstanceNumber  \
# patient_id laterality
# D1-0001    R                              2                 2
# D1-0002    L                              2                 2
# ...                                     ...               ...
# D2-0749    L                              2                 2
#            R                              2                 2
#
#                        __PixelIntensityRelationship  __CodingSchemeDesignator  \
# patient_id laterality
# D1-0001    R                                      2                         2
# D1-0002    L                                      2                         2
# ...                                             ...                       ...
# D2-0749    L                                      2                         2
#            R                                      2                         2
#
#                        __LossyImageCompression  __OrganExposed  \
# patient_id laterality
# D1-0001    R                                 2               2
# D1-0002    L                                 2               2
# ...                                        ...             ...
# D2-0749    L                                 2               2
#            R                                 2               2
#
#                        __LongitudinalTemporalInformationModified  \
# patient_id laterality
# D1-0001    R                                                   2
# D1-0002    L                                                   2
# ...                                                          ...
# D2-0749    L                                                   2
#            R                                                   2
#
#                        __StudyInstanceUID  __SOPInstanceUID  __ContentDate  \
# patient_id laterality
# D1-0001    R                            2                 2              2
# D1-0002    L                            2                 2              2
# ...                                   ...               ...            ...
# D2-0749    L                            2                 2              2
#            R                            2                 2              2
#
#                        __Modality  __PatientID  __InstanceCreationDate  \
# patient_id laterality
# D1-0001    R                    2            2                       2
# D1-0002    L                    2            2                       2
# ...                           ...          ...                     ...
# D2-0749    L                    2            2                       2
#            R                    2            2                       2
#
#                        __PresentationLUTShape  __PresentationIntentType  \
# patient_id laterality
# D1-0001    R                                2                         2
# D1-0002    L                                2                         2
# ...                                       ...                       ...
# D2-0749    L                                2                         2
#            R                                2                         2
#
#                        __RescaleIntercept  __SeriesDate  __BodyPartExamined  \
# patient_id laterality
# D1-0001    R                            2             2                   2
# D1-0002    L                            2             2                   2
# ...                                   ...           ...                 ...
# D2-0749    L                            2             2                   2
#            R                            2             2                   2
#
#                        __ReferringPhysicianName  __SeriesTime  __Manufacturer  \
# patient_id laterality
# D1-0001    R                                  2             2               2
# D1-0002    L                                  2             2               2
# ...                                         ...           ...             ...
# D2-0749    L                                  2             2               2
#            R                                  2             2               2
#
#                        __BitsAllocated  __PatientIdentityRemoved  __Columns  \
# patient_id laterality
# D1-0001    R                         2                         2          2
# D1-0002    L                         2                         2          2
# ...                                ...                       ...        ...
# D2-0749    L                         2                         2          2
#            R                         2                         2          2
#
#                        __SpecificCharacterSet  __WindowCenterWidthExplanation  \
# patient_id laterality
# D1-0001    R                                2                               2
# D1-0002    L                                2                               2
# ...                                       ...                             ...
# D2-0749    L                                2                               2
#            R                                2                               2
#
#                        __VOILUTFunction  __AcquisitionTime  \
# patient_id laterality
# D1-0001    R                          2                  2
# D1-0002    L                          2                  2
# ...                                 ...                ...
# D2-0749    L                          2                  2
#            R                          2                  2
#
#                        __ViewModifierCodeSequence  __Rows  __StudyTime
# patient_id laterality
# D1-0001    R                                    2       2            2
# D1-0002    L                                    2       2            2
# ...                                           ...     ...          ...
# D2-0749    L                                    2       2            2
#            R                                    2       2            2
#
# [2601 rows x 69 columns]

# %%
dicom_df.laterality.value_counts()
# Out:
# L    2682
# R    2520
# Name: laterality, dtype: int64

# %%
dicom_df.patient_id.nunique()
# Out:
# 1775

# %%
df.patient_id.nunique()
# Out:
# 1775

# %%
df
# Out:
#      patient_id laterality  Age  number    abnormality classification  \
# 0       D1-0001          R   44       2  calcification         Benign
# 1       D1-0002          L   40       2  calcification         Benign
# ...         ...        ...  ...     ...            ...            ...
# 1870    D2-0748          R   29       2           mass      Malignant
# 1871    D2-0749          L   42       2           mass      Malignant
#
#         subtype
# 0           NaN
# 1           NaN
# ...         ...
# 1870  Luminal B
# 1871  Luminal B
#
# [1872 rows x 7 columns]

# %%
merged = pd.merge(
    dicom_df,
    df,
    how="outer",
    on=['patient_id', 'laterality'],
    left_on=None,
    right_on=None,
    left_index=False,
    right_index=False,
    sort=False,
    suffixes=("__", ""),
    copy=True,
    indicator=False,
#     validate='1:1',
)
merged
# Out:
#      patient_id   __image_id        __  __HighBit  \
# 0       D1-0830  D1-0830_1-1  12391759          7
# 1       D1-0830  D1-0830_1-2  12391759          7
# ...         ...          ...       ...        ...
# 5200    D2-0448  D2-0448_1-4  12391759          7
# 5201    D2-0448  D2-0448_1-3  12391759          7
#
#       __PixelIntensityRelationshipSign __AcquisitionContextSequence  \
# 0                                   -1                           []
# 1                                   -1                           []
# ...                                ...                          ...
# 5200                                -1                           []
# 5201                                -1                           []
#
#      __StudyDate  __WindowCenter  __WindowWidth __PositionerType  \
# 0       20100718           128.0          256.0     MAMMOGRAPHIC
# 1       20100718           128.0          256.0     MAMMOGRAPHIC
# ...          ...             ...            ...              ...
# 5200    20100718           128.0          256.0     MAMMOGRAPHIC
# 5201    20100718           128.0          256.0     MAMMOGRAPHIC
#
#                                    __InstanceCreatorUID __DetectorType  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...   SCINTILLATOR
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...   SCINTILLATOR
# ...                                                 ...            ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...   SCINTILLATOR
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...   SCINTILLATOR
#
#       __RescaleSlope         __ImageType __AccessionNumber __RescaleType  \
# 0                1.0  [DERIVED, PRIMARY]                              US
# 1                1.0  [DERIVED, PRIMARY]                              US
# ...              ...                 ...               ...           ...
# 5200             1.0  [DERIVED, PRIMARY]                              US
# 5201             1.0  [DERIVED, PRIMARY]                              US
#
#                    __DeidentificationMethodCodeSequence  \
# 0     [[(0008, 0100) Code Value                     ...
# 1     [[(0008, 0100) Code Value                     ...
# ...                                                 ...
# 5200  [[(0008, 0100) Code Value                     ...
# 5201  [[(0008, 0100) Code Value                     ...
#
#       __PixelRepresentation __PatientSex        __ImagerPixelSpacing  \
# 0                         0            F  [0.094090909, 0.094090909]
# 1                         0            F  [0.094090909, 0.094090909]
# ...                     ...          ...                         ...
# 5200                      0            F  [0.094090909, 0.094090909]
# 5201                      0            F  [0.094090909, 0.094090909]
#
#               __PatientName __PatientBirthDate  \
# 0     (D, 1, -, 0, 8, 3, 0)
# 1     (D, 1, -, 0, 8, 3, 0)
# ...                     ...                ...
# 5200  (D, 2, -, 0, 4, 4, 8)
# 5201  (D, 2, -, 0, 4, 4, 8)
#
#                             __DeidentificationMethod __AcquisitionDate  \
# 0     Per DICOM PS 3.15 AnnexE. Details in 0012,0064          20100718
# 1     Per DICOM PS 3.15 AnnexE. Details in 0012,0064          20100718
# ...                                              ...               ...
# 5200  Per DICOM PS 3.15 AnnexE. Details in 0012,0064          20100718
# 5201  Per DICOM PS 3.15 AnnexE. Details in 0012,0064          20100718
#
#      __PatientAge  __SeriesNumber __PhotometricInterpretation  \
# 0            063Y               1                 MONOCHROME2
# 1            063Y               1                 MONOCHROME2
# ...           ...             ...                         ...
# 5200         053Y               1                 MONOCHROME2
# 5201         053Y               1                 MONOCHROME2
#
#                                     __SeriesInstanceUID __ContentTime  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.320712920134...        000000
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.320712920134...        000000
# ...                                                 ...           ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.378084371300...        000000
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.378084371300...        000000
#
#      __InstanceCreationTime __StudyID __BurnedInAnnotation  __BitsStored  \
# 0                    120428                             NO             8
# 1                    120429                             NO             8
# ...                     ...       ...                  ...           ...
# 5200                 124254                             NO             8
# 5201                 124253                             NO             8
#
#      __CodeValue          __CodeMeaning  \
# 0      399162004          cranio-caudal
# 1      399368009  medio-lateral oblique
# ...          ...                    ...
# 5200   399368009  medio-lateral oblique
# 5201   399162004          cranio-caudal
#
#                                __AnatomicRegionSequence  \
# 0     [[(0008, 0100) Code Value                     ...
# 1     [[(0008, 0100) Code Value                     ...
# ...                                                 ...
# 5200  [[(0008, 0100) Code Value                     ...
# 5201  [[(0008, 0100) Code Value                     ...
#
#                     __SOPClassUID  \
# 0     1.2.840.10008.5.1.4.1.1.1.2
# 1     1.2.840.10008.5.1.4.1.1.1.2
# ...                           ...
# 5200  1.2.840.10008.5.1.4.1.1.1.2
# 5201  1.2.840.10008.5.1.4.1.1.1.2
#
#                                      __ViewCodeSequence  __SamplesPerPixel  \
# 0     [[(0008, 0100) Code Value                     ...                  1
# 1     [[(0008, 0100) Code Value                     ...                  1
# ...                                                 ...                ...
# 5200  [[(0008, 0100) Code Value                     ...                  1
# 5201  [[(0008, 0100) Code Value                     ...                  1
#
#      __PatientOrientation  __InstanceNumber __PixelIntensityRelationship  \
# 0                  [A, R]                 1                          LOG
# 1                 [A, FR]                 2                          LOG
# ...                   ...               ...                          ...
# 5200              [P, FL]                 4                          LOG
# 5201               [P, L]                 3                          LOG
#
#      __CodingSchemeDesignator __LossyImageCompression __OrganExposed  \
# 0                         SCT                      00         BREAST
# 1                         SCT                      00         BREAST
# ...                       ...                     ...            ...
# 5200                      SCT                      00         BREAST
# 5201                      SCT                      00         BREAST
#
#      __LongitudinalTemporalInformationModified  \
# 0                                     MODIFIED
# 1                                     MODIFIED
# ...                                        ...
# 5200                                  MODIFIED
# 5201                                  MODIFIED
#
#                                      __StudyInstanceUID  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.160257839898...
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.160257839898...
# ...                                                 ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.744773683160...
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.744773683160...
#
#                                        __SOPInstanceUID __ContentDate  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.244359496749...      20100718
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.320677583371...      20100718
# ...                                                 ...           ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.704200754105...      20100718
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.170184140124...      20100718
#
#      laterality __Modality __PatientID __InstanceCreationDate  \
# 0             L         MG     D1-0830               20170818
# 1             L         MG     D1-0830               20170818
# ...         ...        ...         ...                    ...
# 5200          R         MG     D2-0448               20170818
# 5201          R         MG     D2-0448               20170818
#
#      __PresentationLUTShape __PresentationIntentType  __RescaleIntercept  \
# 0                  IDENTITY         FOR PRESENTATION                 0.0
# 1                  IDENTITY         FOR PRESENTATION                 0.0
# ...                     ...                      ...                 ...
# 5200               IDENTITY         FOR PRESENTATION                 0.0
# 5201               IDENTITY         FOR PRESENTATION                 0.0
#
#      __SeriesDate __BodyPartExamined __ReferringPhysicianName __SeriesTime  \
# 0        20100718             BREAST                       ()       000000
# 1        20100718             BREAST                       ()       000000
# ...           ...                ...                      ...          ...
# 5200     20100718             BREAST                       ()       000000
# 5201     20100718             BREAST                       ()       000000
#
#      __Manufacturer  __BitsAllocated __PatientIdentityRemoved  __Columns  \
# 0                                  8                      YES       1914
# 1                                  8                      YES       1914
# ...             ...              ...                      ...        ...
# 5200                               8                      YES       1914
# 5201                               8                      YES       1914
#
#      __SpecificCharacterSet __WindowCenterWidthExplanation __VOILUTFunction  \
# 0                ISO_IR 100       Full width of 8 bit data          SIGMOID
# 1                ISO_IR 100       Full width of 8 bit data          SIGMOID
# ...                     ...                            ...              ...
# 5200             ISO_IR 100       Full width of 8 bit data          SIGMOID
# 5201             ISO_IR 100       Full width of 8 bit data          SIGMOID
#
#      __AcquisitionTime __ViewModifierCodeSequence  __Rows __StudyTime   Age  \
# 0               000000                         []    2294      000000  63.0
# 1               000000                         []    2294      000000  63.0
# ...                ...                        ...     ...         ...   ...
# 5200            000000                         []    2294      000000   NaN
# 5201            000000                         []    2294      000000   NaN
#
#       number abnormality classification subtype
# 0        2.0        mass         Benign     NaN
# 1        2.0        mass         Benign     NaN
# ...      ...         ...            ...     ...
# 5200     NaN         NaN            NaN     NaN
# 5201     NaN         NaN            NaN     NaN
#
# [5202 rows x 76 columns]

# %%
merged.at[0, '__ViewCodeSequence']
# Out:
# <Sequence, length 1>

# %%
merged.columns
# Out:
# Index(['patient_id', '__image_id', '__', '__HighBit',
#        '__PixelIntensityRelationshipSign', '__AcquisitionContextSequence',
#        '__StudyDate', '__WindowCenter', '__WindowWidth', '__PositionerType',
#        '__InstanceCreatorUID', '__DetectorType', '__RescaleSlope',
#        '__ImageType', '__AccessionNumber', '__RescaleType',
#        '__DeidentificationMethodCodeSequence', '__PixelRepresentation',
#        '__PatientSex', '__ImagerPixelSpacing', '__PatientName',
#        '__PatientBirthDate', '__DeidentificationMethod', '__AcquisitionDate',
#        '__PatientAge', '__SeriesNumber', '__PhotometricInterpretation',
#        '__SeriesInstanceUID', '__ContentTime', '__InstanceCreationTime',
#        '__StudyID', '__BurnedInAnnotation', '__BitsStored', '__CodeValue',
#        '__CodeMeaning', '__AnatomicRegionSequence', '__SOPClassUID',
#        '__ViewCodeSequence', '__SamplesPerPixel', '__PatientOrientation',
#        '__InstanceNumber', '__PixelIntensityRelationship',
#        '__CodingSchemeDesignator', '__LossyImageCompression', '__OrganExposed',
#        '__LongitudinalTemporalInformationModified', '__StudyInstanceUID',
#        '__SOPInstanceUID', '__ContentDate', 'laterality', '__Modality',
#        '__PatientID', '__InstanceCreationDate', '__PresentationLUTShape',
#        '__PresentationIntentType', '__RescaleIntercept', '__SeriesDate',
#        '__BodyPartExamined', '__ReferringPhysicianName', '__SeriesTime',
#        '__Manufacturer', '__BitsAllocated', '__PatientIdentityRemoved',
#        '__Columns', '__SpecificCharacterSet', '__WindowCenterWidthExplanation',
#        '__VOILUTFunction', '__AcquisitionTime', '__ViewModifierCodeSequence',
#        '__Rows', '__StudyTime', 'Age', 'number', 'abnormality',
#        'classification', 'subtype'],
#       dtype='object')

# %%
merged = merged[
    ['patient_id', '__image_id', 'laterality', 'Age', 'number', 'abnormality', 'classification', 'subtype',
     '__VOILUTFunction', '__WindowCenter', '__WindowWidth', '__WindowCenterWidthExplanation',
     '__RescaleSlope', '__RescaleIntercept', '__Columns', '__Rows',
       '__SOPInstanceUID', '__LossyImageCompression',
       '__CodeMeaning', '__StudyID', '__PatientOrientation',
       '__SpecificCharacterSet', '__InstanceCreatorUID', '__PositionerType',
       '__PhotometricInterpretation', '__BitsAllocated',
       '__StudyDate', '__PatientName', '__ContentTime',
       '__PixelIntensityRelationship', '__Modality',
       '__PresentationIntentType', '__AcquisitionTime', '__BodyPartExamined', '__HighBit',
       '__PatientIdentityRemoved', '__BitsStored', '__InstanceCreationTime',
       '__StudyTime', '__SeriesTime', '__PatientBirthDate', '__ImageType',
       '__RescaleType', '__SeriesInstanceUID', '__ReferringPhysicianName',
       '__ContentDate', '__InstanceCreationDate',
       '__PixelIntensityRelationshipSign', '__SeriesNumber',
       '__StudyInstanceUID', '__PatientID', '__DetectorType',
       '__SamplesPerPixel', '__SOPClassUID', '__PixelRepresentation', '__CodeValue',
       '__OrganExposed', '__InstanceNumber', '__AccessionNumber',
       '__SeriesDate', '__AcquisitionDate',
       '__PatientAge',
       '__BurnedInAnnotation', '__PresentationLUTShape',
       '__Manufacturer', '__DeidentificationMethod', '__ImagerPixelSpacing',
       '__PatientSex', ]
]
merged
# Out:
#      patient_id   __image_id laterality   Age  number abnormality  \
# 0       D1-0830  D1-0830_1-1          L  63.0     2.0        mass
# 1       D1-0830  D1-0830_1-2          L  63.0     2.0        mass
# ...         ...          ...        ...   ...     ...         ...
# 5200    D2-0448  D2-0448_1-4          R   NaN     NaN         NaN
# 5201    D2-0448  D2-0448_1-3          R   NaN     NaN         NaN
#
#      classification subtype __VOILUTFunction  __WindowCenter  __WindowWidth  \
# 0            Benign     NaN          SIGMOID           128.0          256.0
# 1            Benign     NaN          SIGMOID           128.0          256.0
# ...             ...     ...              ...             ...            ...
# 5200            NaN     NaN          SIGMOID           128.0          256.0
# 5201            NaN     NaN          SIGMOID           128.0          256.0
#
#      __WindowCenterWidthExplanation  __RescaleSlope  __RescaleIntercept  \
# 0          Full width of 8 bit data             1.0                 0.0
# 1          Full width of 8 bit data             1.0                 0.0
# ...                             ...             ...                 ...
# 5200       Full width of 8 bit data             1.0                 0.0
# 5201       Full width of 8 bit data             1.0                 0.0
#
#       __Columns  __Rows                                   __SOPInstanceUID  \
# 0          1914    2294  1.3.6.1.4.1.14519.5.2.1.1239.1759.244359496749...
# 1          1914    2294  1.3.6.1.4.1.14519.5.2.1.1239.1759.320677583371...
# ...         ...     ...                                                ...
# 5200       1914    2294  1.3.6.1.4.1.14519.5.2.1.1239.1759.704200754105...
# 5201       1914    2294  1.3.6.1.4.1.14519.5.2.1.1239.1759.170184140124...
#
#      __LossyImageCompression          __CodeMeaning __StudyID  \
# 0                         00          cranio-caudal
# 1                         00  medio-lateral oblique
# ...                      ...                    ...       ...
# 5200                      00  medio-lateral oblique
# 5201                      00          cranio-caudal
#
#      __PatientOrientation __SpecificCharacterSet  \
# 0                  [A, R]             ISO_IR 100
# 1                 [A, FR]             ISO_IR 100
# ...                   ...                    ...
# 5200              [P, FL]             ISO_IR 100
# 5201               [P, L]             ISO_IR 100
#
#                                    __InstanceCreatorUID __PositionerType  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...     MAMMOGRAPHIC
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...     MAMMOGRAPHIC
# ...                                                 ...              ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...     MAMMOGRAPHIC
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...     MAMMOGRAPHIC
#
#      __PhotometricInterpretation  __BitsAllocated __StudyDate  \
# 0                    MONOCHROME2                8    20100718
# 1                    MONOCHROME2                8    20100718
# ...                          ...              ...         ...
# 5200                 MONOCHROME2                8    20100718
# 5201                 MONOCHROME2                8    20100718
#
#               __PatientName __ContentTime __PixelIntensityRelationship  \
# 0     (D, 1, -, 0, 8, 3, 0)        000000                          LOG
# 1     (D, 1, -, 0, 8, 3, 0)        000000                          LOG
# ...                     ...           ...                          ...
# 5200  (D, 2, -, 0, 4, 4, 8)        000000                          LOG
# 5201  (D, 2, -, 0, 4, 4, 8)        000000                          LOG
#
#      __Modality __PresentationIntentType __AcquisitionTime __BodyPartExamined  \
# 0            MG         FOR PRESENTATION            000000             BREAST
# 1            MG         FOR PRESENTATION            000000             BREAST
# ...         ...                      ...               ...                ...
# 5200         MG         FOR PRESENTATION            000000             BREAST
# 5201         MG         FOR PRESENTATION            000000             BREAST
#
#       __HighBit __PatientIdentityRemoved  __BitsStored __InstanceCreationTime  \
# 0             7                      YES             8                 120428
# 1             7                      YES             8                 120429
# ...         ...                      ...           ...                    ...
# 5200          7                      YES             8                 124254
# 5201          7                      YES             8                 124253
#
#      __StudyTime __SeriesTime __PatientBirthDate         __ImageType  \
# 0         000000       000000                     [DERIVED, PRIMARY]
# 1         000000       000000                     [DERIVED, PRIMARY]
# ...          ...          ...                ...                 ...
# 5200      000000       000000                     [DERIVED, PRIMARY]
# 5201      000000       000000                     [DERIVED, PRIMARY]
#
#      __RescaleType                                __SeriesInstanceUID  \
# 0               US  1.3.6.1.4.1.14519.5.2.1.1239.1759.320712920134...
# 1               US  1.3.6.1.4.1.14519.5.2.1.1239.1759.320712920134...
# ...            ...                                                ...
# 5200            US  1.3.6.1.4.1.14519.5.2.1.1239.1759.378084371300...
# 5201            US  1.3.6.1.4.1.14519.5.2.1.1239.1759.378084371300...
#
#      __ReferringPhysicianName __ContentDate __InstanceCreationDate  \
# 0                          ()      20100718               20170818
# 1                          ()      20100718               20170818
# ...                       ...           ...                    ...
# 5200                       ()      20100718               20170818
# 5201                       ()      20100718               20170818
#
#       __PixelIntensityRelationshipSign  __SeriesNumber  \
# 0                                   -1               1
# 1                                   -1               1
# ...                                ...             ...
# 5200                                -1               1
# 5201                                -1               1
#
#                                      __StudyInstanceUID __PatientID  \
# 0     1.3.6.1.4.1.14519.5.2.1.1239.1759.160257839898...     D1-0830
# 1     1.3.6.1.4.1.14519.5.2.1.1239.1759.160257839898...     D1-0830
# ...                                                 ...         ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.744773683160...     D2-0448
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.744773683160...     D2-0448
#
#      __DetectorType  __SamplesPerPixel                __SOPClassUID  \
# 0      SCINTILLATOR                  1  1.2.840.10008.5.1.4.1.1.1.2
# 1      SCINTILLATOR                  1  1.2.840.10008.5.1.4.1.1.1.2
# ...             ...                ...                          ...
# 5200   SCINTILLATOR                  1  1.2.840.10008.5.1.4.1.1.1.2
# 5201   SCINTILLATOR                  1  1.2.840.10008.5.1.4.1.1.1.2
#
#       __PixelRepresentation __CodeValue __OrganExposed  __InstanceNumber  \
# 0                         0   399162004         BREAST                 1
# 1                         0   399368009         BREAST                 2
# ...                     ...         ...            ...               ...
# 5200                      0   399368009         BREAST                 4
# 5201                      0   399162004         BREAST                 3
#
#      __AccessionNumber __SeriesDate __AcquisitionDate __PatientAge  \
# 0                          20100718          20100718         063Y
# 1                          20100718          20100718         063Y
# ...                ...          ...               ...          ...
# 5200                       20100718          20100718         053Y
# 5201                       20100718          20100718         053Y
#
#      __BurnedInAnnotation __PresentationLUTShape __Manufacturer  \
# 0                      NO               IDENTITY
# 1                      NO               IDENTITY
# ...                   ...                    ...            ...
# 5200                   NO               IDENTITY
# 5201                   NO               IDENTITY
#
#                             __DeidentificationMethod  \
# 0     Per DICOM PS 3.15 AnnexE. Details in 0012,0064
# 1     Per DICOM PS 3.15 AnnexE. Details in 0012,0064
# ...                                              ...
# 5200  Per DICOM PS 3.15 AnnexE. Details in 0012,0064
# 5201  Per DICOM PS 3.15 AnnexE. Details in 0012,0064
#
#             __ImagerPixelSpacing __PatientSex
# 0     [0.094090909, 0.094090909]            F
# 1     [0.094090909, 0.094090909]            F
# ...                          ...          ...
# 5200  [0.094090909, 0.094090909]            F
# 5201  [0.094090909, 0.094090909]            F
#
# [5202 rows x 68 columns]

# %%
merged[merged['classification'].isna()]
# Out:
#      patient_id   __image_id laterality  Age  number abnormality  \
# 8       D2-0138  D2-0138_1-1          L  NaN     NaN         NaN
# 9       D2-0138  D2-0138_1-2          L  NaN     NaN         NaN
# ...         ...          ...        ...  ...     ...         ...
# 5200    D2-0448  D2-0448_1-4          R  NaN     NaN         NaN
# 5201    D2-0448  D2-0448_1-3          R  NaN     NaN         NaN
#
#      classification subtype __VOILUTFunction  __WindowCenter  __WindowWidth  \
# 8               NaN     NaN          SIGMOID           128.0          256.0
# 9               NaN     NaN          SIGMOID           128.0          256.0
# ...             ...     ...              ...             ...            ...
# 5200            NaN     NaN          SIGMOID           128.0          256.0
# 5201            NaN     NaN          SIGMOID           128.0          256.0
#
#      __WindowCenterWidthExplanation  __RescaleSlope  __RescaleIntercept  \
# 8          Full width of 8 bit data             1.0                 0.0
# 9          Full width of 8 bit data             1.0                 0.0
# ...                             ...             ...                 ...
# 5200       Full width of 8 bit data             1.0                 0.0
# 5201       Full width of 8 bit data             1.0                 0.0
#
#       __Columns  __Rows                                   __SOPInstanceUID  \
# 8          1914    2294  1.3.6.1.4.1.14519.5.2.1.1239.1759.208719161957...
# 9          1914    2294  1.3.6.1.4.1.14519.5.2.1.1239.1759.146858404676...
# ...         ...     ...                                                ...
# 5200       1914    2294  1.3.6.1.4.1.14519.5.2.1.1239.1759.704200754105...
# 5201       1914    2294  1.3.6.1.4.1.14519.5.2.1.1239.1759.170184140124...
#
#      __LossyImageCompression          __CodeMeaning __StudyID  \
# 8                         00          cranio-caudal
# 9                         00  medio-lateral oblique
# ...                      ...                    ...       ...
# 5200                      00  medio-lateral oblique
# 5201                      00          cranio-caudal
#
#      __PatientOrientation __SpecificCharacterSet  \
# 8                  [A, R]             ISO_IR 100
# 9                 [A, FR]             ISO_IR 100
# ...                   ...                    ...
# 5200              [P, FL]             ISO_IR 100
# 5201               [P, L]             ISO_IR 100
#
#                                    __InstanceCreatorUID __PositionerType  \
# 8     1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...     MAMMOGRAPHIC
# 9     1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...     MAMMOGRAPHIC
# ...                                                 ...              ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...     MAMMOGRAPHIC
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...     MAMMOGRAPHIC
#
#      __PhotometricInterpretation  __BitsAllocated __StudyDate  \
# 8                    MONOCHROME2                8    20100718
# 9                    MONOCHROME2                8    20100718
# ...                          ...              ...         ...
# 5200                 MONOCHROME2                8    20100718
# 5201                 MONOCHROME2                8    20100718
#
#               __PatientName __ContentTime __PixelIntensityRelationship  \
# 8     (D, 2, -, 0, 1, 3, 8)        000000                          LOG
# 9     (D, 2, -, 0, 1, 3, 8)        000000                          LOG
# ...                     ...           ...                          ...
# 5200  (D, 2, -, 0, 4, 4, 8)        000000                          LOG
# 5201  (D, 2, -, 0, 4, 4, 8)        000000                          LOG
#
#      __Modality __PresentationIntentType __AcquisitionTime __BodyPartExamined  \
# 8            MG         FOR PRESENTATION            000000             BREAST
# 9            MG         FOR PRESENTATION            000000             BREAST
# ...         ...                      ...               ...                ...
# 5200         MG         FOR PRESENTATION            000000             BREAST
# 5201         MG         FOR PRESENTATION            000000             BREAST
#
#       __HighBit __PatientIdentityRemoved  __BitsStored __InstanceCreationTime  \
# 8             7                      YES             8                 123206
# 9             7                      YES             8                 123207
# ...         ...                      ...           ...                    ...
# 5200          7                      YES             8                 124254
# 5201          7                      YES             8                 124253
#
#      __StudyTime __SeriesTime __PatientBirthDate         __ImageType  \
# 8         000000       000000                     [DERIVED, PRIMARY]
# 9         000000       000000                     [DERIVED, PRIMARY]
# ...          ...          ...                ...                 ...
# 5200      000000       000000                     [DERIVED, PRIMARY]
# 5201      000000       000000                     [DERIVED, PRIMARY]
#
#      __RescaleType                                __SeriesInstanceUID  \
# 8               US  1.3.6.1.4.1.14519.5.2.1.1239.1759.160968165824...
# 9               US  1.3.6.1.4.1.14519.5.2.1.1239.1759.160968165824...
# ...            ...                                                ...
# 5200            US  1.3.6.1.4.1.14519.5.2.1.1239.1759.378084371300...
# 5201            US  1.3.6.1.4.1.14519.5.2.1.1239.1759.378084371300...
#
#      __ReferringPhysicianName __ContentDate __InstanceCreationDate  \
# 8                          ()      20100718               20170818
# 9                          ()      20100718               20170818
# ...                       ...           ...                    ...
# 5200                       ()      20100718               20170818
# 5201                       ()      20100718               20170818
#
#       __PixelIntensityRelationshipSign  __SeriesNumber  \
# 8                                   -1               1
# 9                                   -1               1
# ...                                ...             ...
# 5200                                -1               1
# 5201                                -1               1
#
#                                      __StudyInstanceUID __PatientID  \
# 8     1.3.6.1.4.1.14519.5.2.1.1239.1759.291802729061...     D2-0138
# 9     1.3.6.1.4.1.14519.5.2.1.1239.1759.291802729061...     D2-0138
# ...                                                 ...         ...
# 5200  1.3.6.1.4.1.14519.5.2.1.1239.1759.744773683160...     D2-0448
# 5201  1.3.6.1.4.1.14519.5.2.1.1239.1759.744773683160...     D2-0448
#
#      __DetectorType  __SamplesPerPixel                __SOPClassUID  \
# 8      SCINTILLATOR                  1  1.2.840.10008.5.1.4.1.1.1.2
# 9      SCINTILLATOR                  1  1.2.840.10008.5.1.4.1.1.1.2
# ...             ...                ...                          ...
# 5200   SCINTILLATOR                  1  1.2.840.10008.5.1.4.1.1.1.2
# 5201   SCINTILLATOR                  1  1.2.840.10008.5.1.4.1.1.1.2
#
#       __PixelRepresentation __CodeValue __OrganExposed  __InstanceNumber  \
# 8                         0   399162004         BREAST                 1
# 9                         0   399368009         BREAST                 2
# ...                     ...         ...            ...               ...
# 5200                      0   399368009         BREAST                 4
# 5201                      0   399162004         BREAST                 3
#
#      __AccessionNumber __SeriesDate __AcquisitionDate __PatientAge  \
# 8                          20100718          20100718         060Y
# 9                          20100718          20100718         060Y
# ...                ...          ...               ...          ...
# 5200                       20100718          20100718         053Y
# 5201                       20100718          20100718         053Y
#
#      __BurnedInAnnotation __PresentationLUTShape __Manufacturer  \
# 8                      NO               IDENTITY
# 9                      NO               IDENTITY
# ...                   ...                    ...            ...
# 5200                   NO               IDENTITY
# 5201                   NO               IDENTITY
#
#                             __DeidentificationMethod  \
# 8     Per DICOM PS 3.15 AnnexE. Details in 0012,0064
# 9     Per DICOM PS 3.15 AnnexE. Details in 0012,0064
# ...                                              ...
# 5200  Per DICOM PS 3.15 AnnexE. Details in 0012,0064
# 5201  Per DICOM PS 3.15 AnnexE. Details in 0012,0064
#
#             __ImagerPixelSpacing __PatientSex
# 8     [0.094090909, 0.094090909]            F
# 9     [0.094090909, 0.094090909]            F
# ...                          ...          ...
# 5200  [0.094090909, 0.094090909]            F
# 5201  [0.094090909, 0.094090909]            F
#
# [1458 rows x 68 columns]

# %%
dicom_df[(dicom_df.patient_id == 'D2-0138') & (dicom_df.laterality == 'L')]
# Out:
#    patient_id   __image_id        __  __HighBit  \
# 8     D2-0138  D2-0138_1-1  12391759          7
# 11    D2-0138  D2-0138_1-2  12391759          7
#
#     __PixelIntensityRelationshipSign __AcquisitionContextSequence __StudyDate  \
# 8                                 -1                           []    20100718
# 11                                -1                           []    20100718
#
#     __WindowCenter  __WindowWidth __PositionerType  \
# 8            128.0          256.0     MAMMOGRAPHIC
# 11           128.0          256.0     MAMMOGRAPHIC
#
#                                  __InstanceCreatorUID __DetectorType  \
# 8   1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...   SCINTILLATOR
# 11  1.3.6.1.4.1.14519.5.2.1.1239.1759.256693145395...   SCINTILLATOR
#
#     __RescaleSlope         __ImageType __AccessionNumber __RescaleType  \
# 8              1.0  [DERIVED, PRIMARY]                              US
# 11             1.0  [DERIVED, PRIMARY]                              US
#
#                  __DeidentificationMethodCodeSequence  __PixelRepresentation  \
# 8   [[(0008, 0100) Code Value                     ...                      0
# 11  [[(0008, 0100) Code Value                     ...                      0
#
#    __PatientSex        __ImagerPixelSpacing          __PatientName  \
# 8             F  [0.094090909, 0.094090909]  (D, 2, -, 0, 1, 3, 8)
# 11            F  [0.094090909, 0.094090909]  (D, 2, -, 0, 1, 3, 8)
#
#    __PatientBirthDate                        __DeidentificationMethod  \
# 8                      Per DICOM PS 3.15 AnnexE. Details in 0012,0064
# 11                     Per DICOM PS 3.15 AnnexE. Details in 0012,0064
#
#    __AcquisitionDate __PatientAge  __SeriesNumber __PhotometricInterpretation  \
# 8           20100718         060Y               1                 MONOCHROME2
# 11          20100718         060Y               1                 MONOCHROME2
#
#                                   __SeriesInstanceUID __ContentTime  \
# 8   1.3.6.1.4.1.14519.5.2.1.1239.1759.160968165824...        000000
# 11  1.3.6.1.4.1.14519.5.2.1.1239.1759.160968165824...        000000
#
#    __InstanceCreationTime __StudyID __BurnedInAnnotation  __BitsStored  \
# 8                  123206                             NO             8
# 11                 123207                             NO             8
#
#    __CodeValue          __CodeMeaning  \
# 8    399162004          cranio-caudal
# 11   399368009  medio-lateral oblique
#
#                              __AnatomicRegionSequence  \
# 8   [[(0008, 0100) Code Value                     ...
# 11  [[(0008, 0100) Code Value                     ...
#
#                   __SOPClassUID  \
# 8   1.2.840.10008.5.1.4.1.1.1.2
# 11  1.2.840.10008.5.1.4.1.1.1.2
#
#                                    __ViewCodeSequence  __SamplesPerPixel  \
# 8   [[(0008, 0100) Code Value                     ...                  1
# 11  [[(0008, 0100) Code Value                     ...                  1
#
#    __PatientOrientation  __InstanceNumber __PixelIntensityRelationship  \
# 8                [A, R]                 1                          LOG
# 11              [A, FR]                 2                          LOG
#
#    __CodingSchemeDesignator __LossyImageCompression __OrganExposed  \
# 8                       SCT                      00         BREAST
# 11                      SCT                      00         BREAST
#
#    __LongitudinalTemporalInformationModified  \
# 8                                   MODIFIED
# 11                                  MODIFIED
#
#                                    __StudyInstanceUID  \
# 8   1.3.6.1.4.1.14519.5.2.1.1239.1759.291802729061...
# 11  1.3.6.1.4.1.14519.5.2.1.1239.1759.291802729061...
#
#                                      __SOPInstanceUID __ContentDate  \
# 8   1.3.6.1.4.1.14519.5.2.1.1239.1759.208719161957...      20100718
# 11  1.3.6.1.4.1.14519.5.2.1.1239.1759.146858404676...      20100718
#
#    laterality __Modality __PatientID __InstanceCreationDate  \
# 8           L         MG     D2-0138               20170818
# 11          L         MG     D2-0138               20170818
#
#    __PresentationLUTShape __PresentationIntentType  __RescaleIntercept  \
# 8                IDENTITY         FOR PRESENTATION                 0.0
# 11               IDENTITY         FOR PRESENTATION                 0.0
#
#    __SeriesDate __BodyPartExamined __ReferringPhysicianName __SeriesTime  \
# 8      20100718             BREAST                       ()       000000
# 11     20100718             BREAST                       ()       000000
#
#    __Manufacturer  __BitsAllocated __PatientIdentityRemoved  __Columns  \
# 8                                8                      YES       1914
# 11                               8                      YES       1914
#
#    __SpecificCharacterSet __WindowCenterWidthExplanation __VOILUTFunction  \
# 8              ISO_IR 100       Full width of 8 bit data          SIGMOID
# 11             ISO_IR 100       Full width of 8 bit data          SIGMOID
#
#    __AcquisitionTime __ViewModifierCodeSequence  __Rows __StudyTime
# 8             000000                         []    2294      000000
# 11            000000                         []    2294      000000

# %%
df[(df.patient_id == 'D2-0138') & (df.laterality == 'R')]
# Out:
#      patient_id laterality  Age  number abnormality classification  \
# 1250    D2-0138          R   60       2        both      Malignant
#
#             subtype
# 1250  HER2-enriched

# %%
merged.classification.fillna('Normal', inplace = True)

# %%
merged[merged['classification'].isna()]

# %%
merged.columns

# %%
merged.classification.hist()

# %%
merged['cancer'] = merged.classification.apply(lambda x: 1 if x=='Malignant' else 0)

# %%
merged.columns

# %%
merged = merged[['patient_id', '__image_id', 'laterality', 'Age', 'cancer', 'number',
       'abnormality', 'classification', 'subtype', '__VOILUTFunction',
       '__WindowCenter', '__WindowWidth', '__WindowCenterWidthExplanation',
       '__RescaleSlope', '__RescaleIntercept', '__Columns', '__Rows',
       '__SOPInstanceUID', '__LossyImageCompression', '__CodeMeaning',
       '__StudyID', '__PatientOrientation', '__SpecificCharacterSet',
       '__InstanceCreatorUID', '__PositionerType',
       '__PhotometricInterpretation', '__BitsAllocated', '__StudyDate',
       '__PatientName', '__ContentTime', '__PixelIntensityRelationship',
       '__Modality', '__PresentationIntentType', '__AcquisitionTime',
       '__BodyPartExamined', '__HighBit', '__PatientIdentityRemoved',
       '__BitsStored', '__InstanceCreationTime', '__StudyTime', '__SeriesTime',
       '__PatientBirthDate', '__ImageType', '__RescaleType',
       '__SeriesInstanceUID', '__ReferringPhysicianName', '__ContentDate',
       '__InstanceCreationDate', '__PixelIntensityRelationshipSign',
       '__SeriesNumber', '__StudyInstanceUID', '__PatientID', '__DetectorType',
       '__SamplesPerPixel', '__SOPClassUID', '__PixelRepresentation',
       '__CodeValue', '__OrganExposed', '__InstanceNumber',
       '__AccessionNumber', '__SeriesDate', '__AcquisitionDate',
       '__PatientAge', '__BurnedInAnnotation', '__PresentationLUTShape',
       '__Manufacturer', '__DeidentificationMethod', '__ImagerPixelSpacing',
       '__PatientSex']]

merged.rename(columns = {
    '__image_id': 'image_id',
    'Age': 'age',
    'number': '_num_images',
}, inplace = True)
merged

# %%
merged.cancer.hist()

# %%
merged.to_csv(os.path.join(ROOT_DIR, 'label_v2.csv'), index = False)

# %%
merged

# %%
# for _name, sub_df in merged.groupby(['patient_id']):
#     assert sub_df.cancer.nunique() == 1

for _name, sub_df in merged.groupby(['patient_id', 'laterality']):
    assert sub_df.cancer.nunique() == 1

# %% [markdown]
# ### BMCD

# %%
ROOT_DIR = '/home/dangnh36/datasets/.comp/rsna/external/bmcd/'
DCM_ROOT_DIR = os.path.join(ROOT_DIR, 'dicoms')

# %%
df = pd.read_csv(os.path.join(ROOT_DIR, 'label.csv'))
df.biopsy_result.fillna('NAN', inplace = True)
df
# Out:
#     dir laterality  age density BIRADS biopsy_result folder_type
# 0     1      Right   57       b     4a        BENIGN  suspicious
# 1     2       Left   64       c     4a        BENIGN  suspicious
# ..  ...        ...  ...     ...    ...           ...         ...
# 98   49       Left   75       a      2           NAN      normal
# 99   50      Right   56       b      2           NAN      normal
#
# [100 rows x 7 columns]

# %%
df.biopsy_result.value_counts()
# Out:
# NAN              50
# BENIGN           21
# NOT AVAILABLE    18
# DCIS              6
# MALIGNANT         5
# Name: biopsy_result, dtype: int64

# %%
df = df[df.biopsy_result.isin(['NAN', 'BENIGN', 'DCIS', 'MALIGNANT'])].reset_index(drop = True)
df

# %%
src_root_dir = DCM_ROOT_DIR
dst_root_dir = os.path.join(ROOT_DIR, 'dicoms_v2')

df['view'] = None
df['image_id'] = None
all_series = []
for i in tqdm(range(len(df))):
    dir_type = df.at[i, 'folder_type']
    dir_name = df.at[i, 'dir']
    dir_parent = 'Suspicious_cases'
    if dir_type == 'normal':
        dir_parent = 'Normal_cases'
    
    src_dir = os.path.join(src_root_dir, str(dir_parent), str(dir_name))
    dst_dir = os.path.join(dst_root_dir, dir_type + '_' + str(dir_name))
    os.makedirs(dst_dir, exist_ok=True)
    names = os.listdir(src_dir)
#     for name in names:
    s = df.loc[i]
    names = [name for name in names if '.dcm' in name.lower()]
    priors = [name for name in names if 'prior' in name]
    recents = [name for name in names if 'recent' in name]
    assert len(priors) == 2 or len(priors) == 0, names
    assert len(recents) == 2, f'{names} and {dir_parent} -{dir_name}'
    for ori_name in names:
        name = ori_name.split('.')[0]
        new_s = s.copy()
        if new_s['biopsy_result'] == 'DCIS' or new_s['biopsy_result'] == 'MALIGNANT':
            if 'prior' in name:
                new_s['biopsy_result'] = 'BENIGN/NORMAL'
        new_name = str(new_s['folder_type']) + '_' + str(new_s['dir']) + name
        new_s['image_id'] =  new_name
        src_path = os.path.join(src_dir, ori_name)
        dst_path = os.path.join(dst_dir, new_name + '.dcm')
        shutil.copy2(src_path, dst_path)
        
        new_s['view'] = name.split('_')[0]
        all_series.append(new_s)

# %%
df = pd.DataFrame(all_series)
df

# %%
df.biopsy_result.value_counts()

# %%
print(df[df.biopsy_result.isin(['MALIGNANT', 'DCIS'])]['image_id'].tolist())

# %%
df.columns

# %%
df['cancer'] = df.biopsy_result.apply(lambda x: 1 if x in ['MALIGNANT', 'DCIS'] else 0)
df.cancer.value_counts()

# %%
df.rename(columns = {
    'dir': 'patient_id',
}, inplace = True)
df

# %%
df['patient_id'] = df['folder_type'] + '_' +  df['patient_id'].apply(str)

# %%
dicom_df = get_dicom_meta(dst_root_dir, df, extension = 'dcm')

# %%
dicom_df.dropna(axis=1, how='all', inplace = True)

# %%
dicom_df

# %%
dicom_df.rename(columns = {name:'__' + name for name in dicom_df.columns if name != 'image_id'}, inplace = True)
merged = pd.merge(
    df,
    dicom_df,
    how="inner",
    on='image_id',
    left_on=None,
    right_on=None,
    left_index=False,
    right_index=False,
    sort=False,
    suffixes=("", "__"),
    copy=True,
    indicator=False,
    validate='1:1',
)
merged

# %%
merged

# %%
print(list(merged.columns))

# %%
merged = merged[['patient_id', 'laterality', 'age', 'density', 'BIRADS', 'biopsy_result', 'folder_type', 'view', 'image_id', 'cancer', '__WindowWidth', '__WindowCenter', '__WindowCenterWidthExplanation', '__RescaleType', '__RescaleSlope', '__RescaleIntercept', '__Rows', '__Columns', '__BitsAllocated', '__BitsStored']]
merged

# %%
merged.to_csv(os.path.join(ROOT_DIR, 'label_v2.csv'), index = False)

# %% [markdown]
# ### CDD-CESM

# %%
ROOT_DIR = '/home/dangnh36/datasets/.comp/rsna/external/cdd_cesm/'
DCM_ROOT_DIR = os.path.join(ROOT_DIR, 'low_energy')

# %%
df = pd.read_csv(os.path.join(ROOT_DIR, 'cdd_cesm.csv'))
df
# Out:
#          Image_name  Patient_ID Side  Type  Age Breast density (ACR) BIRADS  \
# 0       P1_L_DM_MLO           1    L    DM   46                    C      4
# 1       P1_L_CM_MLO           1    L  CESM   46                    _      4
# ...             ...         ...  ...   ...  ...                  ...    ...
# 2004   P326_L_CM_CC         326    L  CESM   51                    _      4
# 2005  P326_L_CM_MLO         326    L  CESM   51                    _      4
#
#                                 Findings View                            Tags  \
# 0              Architectural distortion   MLO          suspicious, distortion
# 1     Heterogenous non mass enhancement   MLO            suspicious, non mass
# ...                                  ...  ...                             ...
# 2004      Segmental non mass enhancement   CC  suspicious non mass, segmental
# 2005      Segmental non mass enhancement  MLO  suspicious non mass, segmental
#
#       Machine Pathology Classification/ Follow up
# 0           1                           Malignant
# 1           1                           Malignant
# ...       ...                                 ...
# 2004        1                           Malignant
# 2005        1                           Malignant
#
# [2006 rows x 12 columns]

# %%
df.Type.value_counts()

# %%
df['image_id'] = df['Image_name'].apply(lambda x: x.replace('DM_', '').replace('CM_', ''))
# df['patient_id'] = df['Image_name'].apply(lambda x: x.split('_')[0])
df

# %%
df['Pathology Classification/ Follow up'].value_counts()
# Out:
# Normal       757
# Malignant    662
# Benign       587
# Name: Pathology Classification/ Follow up, dtype: int64

# %%
for image_name, sub_df in df.groupby('image_id'):
    sub_df = sub_df.reset_index(drop = True)
    if sub_df.at[0, 'Pathology Classification/ Follow up'] == 'Malignant':
        assert sub_df['Pathology Classification/ Follow up'].nunique() == 1, sub_df

# %%
df = df[df.Type == 'DM'].reset_index(drop = True)
df

# %%
df.columns

# %%
df.rename(columns = {
    'Image_name': 'image_name',
    'Patient_ID': 'patient_id',
    'Side': 'laterality',
    'Age': 'age',
    'Breast density (ACR)': 'density',
    'Findings': 'findings',
    'View': 'view',
    'Tags': 'tags',
    'Machine': 'machine_id',
    'Pathology Classification/ Follow up': 'classification',
}, inplace = True)
df.columns

# %%
df = df[['patient_id', 'image_id', 'laterality', 'view', 'image_name', 'age', 'density', 'BIRADS',
       'findings', 'tags', 'machine_id', 'classification', 'Type']]
df

# %%
df.classification.value_counts()

# %%
df['cancer'] = df.classification.apply(lambda x: 1 if x == 'Malignant' else 0)
df

# %%
df.image_id.nunique()

# %%
df.cancer.value_counts()

# %%
df.to_csv(os.path.join(ROOT_DIR, 'label_v2.csv'), index = False)

# %%
df = pd.read_csv(os.path.join(ROOT_DIR, 'label_v2.csv'))
df
# Out:
#       patient_id    image_id laterality view     image_name  age density  \
# 0              1    P1_L_MLO          L  MLO    P1_L_DM_MLO   46       C
# 1              2     P2_R_CC          R   CC     P2_R_DM_CC   31       C
# ...          ...         ...        ...  ...            ...  ...     ...
# 1001         326   P326_L_CC          L   CC   P326_L_DM_CC   51       C
# 1002         326  P326_L_MLO          L  MLO  P326_L_DM_MLO   51       C
#
#      BIRADS                                           findings  \
# 0         4                          Architectural distortion
# 1       3$2  Multiple equal density  masses$Benign macrocal...
# ...     ...                                                ...
# 1001      3                    Asymmetrical increased density
# 1002      3                    Asymmetrical increased density
#
#                                     tags  machine_id classification Type  \
# 0                 suspicious, distortion           1      Malignant   DM
# 1     benign, masses, macrocalcification           2         Benign   DM
# ...                                  ...         ...            ...  ...
# 1001                           asymmetry           1      Malignant   DM
# 1002                           asymmetry           1      Malignant   DM
#
#       cancer
# 0          1
# 1          0
# ...      ...
# 1001       1
# 1002       1
#
# [1003 rows x 14 columns]

# %%
df['image_id']  = df['image_id'].apply(lambda x: x.strip())
